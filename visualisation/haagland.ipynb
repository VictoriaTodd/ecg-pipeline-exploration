# %%
import numpy as np
import mne
import matplotlib.pyplot as plt

# %%
raw = mne.io.read_raw_edf("../../../Data/haaglanden-medisch-centrum-sleep-staging-database-1.1/recordings/SN001.edf", preload=True)
# Out:
# Extracting EDF parameters from /home/victoria/Documents/Uni/2025 T1/SIT723/Data/haaglanden-medisch-centrum-sleep-staging-database-1.1/recordings/SN001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6566399  =      0.000 ... 25649.996 secs...
# /tmp/ipykernel_379629/639661091.py:1: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf("../../../Data/haaglanden-medisch-centrum-sleep-staging-database-1.1/recordings/SN001.edf", preload=True)
# /tmp/ipykernel_379629/639661091.py:1: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf("../../../Data/haaglanden-medisch-centrum-sleep-staging-database-1.1/recordings/SN001.edf", preload=True)

# %%
print(raw.info)
print(raw.info.ch_names)
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG F4-M1, EEG C4-M1, EEG O2-M1, EEG C3-M2, EMG chin, EOG E1-M2, ...
#  chs: 8 EEG
#  custom_ref_applied: False
#  highpass: 1.0 Hz
#  lowpass: 35.0 Hz
#  meas_date: 2001-01-01 23:59:30 UTC
#  nchan: 8
#  projs: []
#  sfreq: 256.0 Hz
#  subject_info: <subject_info | his_id: SN001, sex: 0, last_name: X>
# >
# ['EEG F4-M1', 'EEG C4-M1', 'EEG O2-M1', 'EEG C3-M2', 'EMG chin', 'EOG E1-M2', 'EOG E2-M2', 'ECG']

# %%
anno = mne.read_annotations("../../../Data/haaglanden-medisch-centrum-sleep-staging-database-1.1/recordings/SN001_sleepscoring.edf")
raw.set_annotations(anno, emit_warning=False)
# Out:
# <RawEDF | SN001.edf, 8 x 6566400 (25650.0 s), ~400.8 MiB, data loaded>

# %%
raw.plot(start=0, duration=10, scalings='auto', picks=['ECG'])
# Out:
# Using qt as 2D backend.
# ...
# Channels marked as bad:
# [np.str_('ECG')]

# %%
raw_2 = mne.io.read_raw_edf("../../../Data/haaglanden-medisch-centrum-sleep-staging-database-1.1/recordings/SN050.edf", preload=True)
anno_2 = mne.read_annotations("../../../Data/haaglanden-medisch-centrum-sleep-staging-database-1.1/recordings/SN050_sleepscoring.edf")
raw_2.set_annotations(anno_2, emit_warning=False)
# Out:
# Extracting EDF parameters from /home/victoria/Documents/Uni/2025 T1/SIT723/Data/haaglanden-medisch-centrum-sleep-staging-database-1.1/recordings/SN050.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7161087  =      0.000 ... 27972.996 secs...
# /tmp/ipykernel_379629/4154644937.py:1: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_2 = mne.io.read_raw_edf("../../../Data/haaglanden-medisch-centrum-sleep-staging-database-1.1/recordings/SN050.edf", preload=True)
# <RawEDF | SN050.edf, 8 x 7161088 (27973.0 s), ~437.1 MiB, data loaded>

# %%
raw_2.plot(start=0, duration=10, scalings='auto', picks=['ECG'])
# Out:
# Channels marked as bad:
# none
